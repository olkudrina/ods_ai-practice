# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'iris.data', header = None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# # Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Step 5. Is there any missing value in the dataframe?

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# # Step 6. Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
df.iloc[10:29, 3:4] = np.nan
df.iloc[10:29, 3:4]
# Out:
#     petal_width
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN

# %%
df.isnull().sum()
# Out:
# sepal_length     0
# sepal_width      0
# petal_length     0
# petal_width     19
# class            0
# dtype: int64

# %% [markdown]
# # Step 7. Good, now lets substitute the NaN values to 1.0

# %%
df.fillna(1.0, inplace = True)
df.iloc[10:29]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 10           5.4          3.7           1.5          1.0  Iris-setosa
# 11           4.8          3.4           1.6          1.0  Iris-setosa
# 12           4.8          3.0           1.4          1.0  Iris-setosa
# 13           4.3          3.0           1.1          1.0  Iris-setosa
# 14           5.8          4.0           1.2          1.0  Iris-setosa
# 15           5.7          4.4           1.5          1.0  Iris-setosa
# 16           5.4          3.9           1.3          1.0  Iris-setosa
# 17           5.1          3.5           1.4          1.0  Iris-setosa
# 18           5.7          3.8           1.7          1.0  Iris-setosa
# 19           5.1          3.8           1.5          1.0  Iris-setosa
# 20           5.4          3.4           1.7          1.0  Iris-setosa
# 21           5.1          3.7           1.5          1.0  Iris-setosa
# 22           4.6          3.6           1.0          1.0  Iris-setosa
# 23           5.1          3.3           1.7          1.0  Iris-setosa
# 24           4.8          3.4           1.9          1.0  Iris-setosa
# 25           5.0          3.0           1.6          1.0  Iris-setosa
# 26           5.0          3.4           1.6          1.0  Iris-setosa
# 27           5.2          3.5           1.5          1.0  Iris-setosa
# 28           5.2          3.4           1.4          1.0  Iris-setosa

# %% [markdown]
# # Step 8. Now let's delete the column class

# %%
df.drop('class', axis = 1, inplace = True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# # Step 9. Set the first 3 rows as NaN

# %%
df[0:3] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1           NaN          NaN           NaN          NaN
# 2           NaN          NaN           NaN          NaN
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# # Step 10. Delete the rows that have NaN

# %%
df.dropna(inplace = True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4
# 6           4.6          3.4           1.4          0.3
# 7           5.0          3.4           1.5          0.2

# %% [markdown]
# # Step 11. Reset the index so it begins with 0 again

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width
# 0      3           4.6          3.1           1.5          0.2
# 1      4           5.0          3.6           1.4          0.2
# 2      5           5.4          3.9           1.7          0.4
# 3      6           4.6          3.4           1.4          0.3
# 4      7           5.0          3.4           1.5          0.2
