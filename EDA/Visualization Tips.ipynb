# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Step 5. Plot the total_bill column histogram

# %%
plt.hist(df['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
plt.scatter(df['total_bill'], df['tip'])

# %% [markdown]
# # Step 7. Create one image with the relationship of total_bill, tip and size.

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
plt.scatter(df['total_bill'], df['tip'], c = df['size'])
plt.legend(handles=plt.scatter(df['total_bill'], df['tip'], c = df['size']).legend_elements()[0], 
           labels=[1,2,3,4,5,6],
           title="size")

# %% [markdown]
# # Step 8. Present the relationship between days and total_bill value

# %%
plt.scatter(df['day'], df['total_bill'])

# %% [markdown]
# # Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(df['tip'], df['day'], hue = df['sex'], color = 'green')

# %% [markdown]
# # Step 10. Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x = df['total_bill'], y = df['time'])

# %% [markdown]
# # Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
df['tip'].hist(by = df['time'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD133941C8>,
# ...
#       dtype=object)

# %% [markdown]
# # Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker

# %%
grid = sns.FacetGrid(data = df, col = 'sex' , hue = 'smoker')
grid.map(sns.scatterplot, 'total_bill', 'tip', data = df)
